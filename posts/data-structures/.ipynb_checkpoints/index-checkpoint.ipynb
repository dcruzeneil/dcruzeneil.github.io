# %% [raw]
# ---
# title: Implementation of Data Structures
# author: Neil Dcruze
# date: '2023-02-14'
# image: "image.jpg"
# description: "Implementation of Various Data Structures in Python"
# format: html
# categories: "Data Structures"
# ---

# %% [markdown]
# # Stack
