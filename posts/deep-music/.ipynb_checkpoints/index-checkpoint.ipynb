# %% [raw]
# ---
# title: Deep Music Classification
# author: Neil Dcruze
# date: '2023-04-25'
# image: "image.jpg"
# description: "NOT FINISHED"
# format: html
# categories: ["Machine Learning", "In Progress"]
# ---
