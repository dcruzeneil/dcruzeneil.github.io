# %% [raw]
# ---
# title: Kernel Logistic Regression
# author: Neil Dcruze
# date: '2023-03-27'
# image: "image.png"
# description: "An Implementation and Testing of Kernel Logistic Regression for Binary Classification of Data with Non-Linear Decision Boundaries"
# format: html
# ---

# %% [markdown]
# <a href="www.google.com">TheCodeGoesHere.py</a>
# # Introduction
