# %% [raw]
# ---
# title: Analyzing Sentiments on Tweets and Intervention for Mental Health Support
# author: Neil Dcruze
# date: '2023-05-15'
# image: "image.png"
# description: "Using machine learning techniques, this project aims to analyze symptoms of depression and anxiety by examining tweets. The goal is to provide insights that aid in delivering appropriate resources to individuals in need, ultimately leading to more effective interventions and improved well-being for communities."
# format: html
# ---
