# %% [raw]
# ---
# title: Analyzing Sentiments on Tweets
# author: Neil Dcruze
# date: '2023-05-15'
# image: "image.png"
# description: "Using machine learning techniques, this project aims to analyze sentiments of text by examining tweets. This could prove useful in understanding symptoms of anxiety and depression."
# format: html
# ---

# %% [markdown]
# Hello
