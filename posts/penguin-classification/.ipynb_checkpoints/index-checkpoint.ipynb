# %% [raw]
# ---
# title: Penguin Classification using Deep Learning
# author: Neil Dcruze
# date: '2023-04-05'
# image: "image.png"
# description: "NOT FINISHED"
# format: html
# categories: "Machine Learning"
# ---
