# %% [raw]
# ---
# title: "good RNN, m.A.A.d city"
# author: Neil Dcruze
# date: '2023-06-21'
# image: "image.png"
# description: "Implementing and Training a Recurrent Neural Network to generate song lyrics in the style of Kendrick Lamar"
# format: html
# categories: ["Machine Learning", "Project"]
# ---
