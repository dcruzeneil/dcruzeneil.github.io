# %% [raw]
# ---
# title: Learning from Dr. Timnit Gebru
# author: Neil Dcruze
# date: '2023-04-19'
# image: "image.png"
# description: "A Reflection on the Work of Dr. Timnit Gebru"
# format: html
# ---
