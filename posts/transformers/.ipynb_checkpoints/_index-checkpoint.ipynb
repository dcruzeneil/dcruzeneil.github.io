# %% [raw]
# ---
# title: "Transformers: Attention Is All You Need"
# author: Neil Dcruze
# date: '2023-06-22'
# image: "image.png"
# description: "An Implementation of a Transformer Neural Network using PyTorch"
# format: html
# categories: ["Machine Learning", "In Progress"]
# published: "false"
# ---
