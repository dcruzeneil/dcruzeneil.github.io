# %% [raw]
# ---
# title: Video Classification using a Convolutional Neural Network
# author: Neil Dcruze
# date: '2023-08-10'
# image: "image.jpg"
# description: "ABCDEFGH"
# format: html
# categories: ["Machine Learning", "Project", "In Progress"]
# ---
