# %% [raw]
# ---
# title: Writing a Neural Network in Python (without using libraries)
# author: Neil Dcruze
# date: '2024-01-17'
# image: "image.jpeg"
# description: "Deconstructing and comprehending the various elements of a neural network. This project explores the mathematics underlying each segment and its contribution to the network's learning process. Focus on building and assembling these components to create a complete neural network."
# format: html
# categories: ["Machine Learning"]
# ---

# %% [markdown]
# ## What is a Neuron?
#
# Let us think of the neuron like a box. There are numerical <b>inputs</b> coming into the neuron, and each of these inputs have associated numerical <b>weights</b>. When the neuron receives the these inputs and their respective weights, it does what is called a <b>weighted sum</b>.
